# %% [markdown]
# **1. OS Info and Directory Listing**
#
# Write a Python program to get the name of the operating system (Platform independent), information of the current operating system, current working directory, print files and directories in the current directory, and raise errors if the path or file name is invalid.

# %%
import os
import platform

# %%
print("Operating System:",os.name)
print("\nInformation of current operating system: ",platform.uname())
print("\nCurrent Working Directory: ",os.getcwd())
print("\nList of files and directories in the current directory:")
print(os.listdir('.'))
print("\nTest if a specified file exis or not:")

filename = 'abc.txt'

try:
    with open(filename, 'r') as f:
        text = f.read()
    print(text)
except IOError:
    print('Not accessed or problem in reading: ' + filename)
# Out:
# Operating System: nt
#
# Information of current operating system:  uname_result(system='Windows', node='LinaDholariya', release='10', version='10.0.19045', machine='AMD64')
#
# Current Working Directory:  C:\Users\LinaDholaiya\Crest-Training\02-Python Practice\02-W3Resource\10-Python Modules
#
# List of files and directories in the current directory:
# ['.ipynb_checkpoints', '01-Built-in Modules.ipynb', '02-Operating System Services.ipynb', 'abc.txt']
#
# Test if a specified file exis or not:
# Hello
