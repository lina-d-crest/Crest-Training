# %% [markdown]
# **1. Find three numbers from an array such that the sum of three numbers equal to zero**

# %%
def fun(n):
    
    if len(n) < 3:
        return []
        
    n.sort()
    r = []
    
    for i in range(len(n)-2):
        l = i+1
        r = len(n)-1
        
        if i!=0 and n[i]==n[i-1]:
            continue
            
        while l<r:            
            if n[l] + n[r] == -n[i]:
                
                r.append([n[i],n[l],n[r]])
                l = l+1
                r = r-1
                
                while n[l]==n[left-1] and l<r:l = l+1
                while n[r]==n[r+1] and l<r: r=r-1
            elif n[l]+n[r]<-n[i]:
                l = l+1    
            else:
                r = r-1
    return r

# %%
 n1=[-1,0,1,2,-1,-4]
n2 = [-25,-10,-7,-3,2,4,8,10]
print(fun(n1))
print(fun(n2))
# Out:
# [[-1, -1, 2], [-1, 0, 1]]
# [[-10, 2, 8], [-7, -3, 10]]
