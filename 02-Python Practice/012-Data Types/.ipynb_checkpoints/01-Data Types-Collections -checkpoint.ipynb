# %% [markdown]
# **1. Iterate Over Elements as Many Times as Its Count**

# %%
from collections import Counter

c = Counter(p=4, q=2, r=0, s=-2)

print(list(c.elements()))
# Out:
# ['p', 'p', 'p', 'p', 'q', 'q']

# %% [markdown]
# **2. Accept subjects, names, and marks, then print in order**
#
# Write a Python program that accepts the number of subjects, subject names and marks. Input the number of subjects and then the subject name and marks separated by a space on the next line. Print the subject name and marks in order of appearance.

# %%
num_subjects = int(input("Enter the number of subjects: "))

subject_marks = []

for _ in range(num_subjects):
    data = input("Enter subject name and marks (separated by space): ")
    name, marks = data.split()
    subject_marks.append((name, int(marks)))

print("\nSubject and Marks:")
for subject, marks in subject_marks:
    print(f"{subject}: {marks}")
# Out:
# Enter the number of subjects:  2
# Enter subject name and marks (separated by space):  Maths 30
# Enter subject name and marks (separated by space):  Science 25
# Subject and Marks:
# Maths: 30
# Science: 25
